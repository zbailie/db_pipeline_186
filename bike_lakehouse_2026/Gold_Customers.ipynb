# %% [markdown]
# #Init

# %%
# Importing functions and window specification utilities from pyspark.sql for use in Spark DataFrame operations
import pyspark.sql.functions as F
from pyspark.sql.window import Window

# %% [markdown]
# # Read from Silver Table/s

# %% [markdown]
# # Business Transformation and Modeling

# %% [markdown]
# # Write to Gold Table
